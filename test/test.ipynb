# %% [markdown]
# # eval
#
# python eval.py --model-folder runs/rvt2  --eval-datafolder ./data/test --tasks all --eval-episodes 25 --log-name test --device 0 --headless --model-name model_99.pth
#
#
# CUDA_VISIBLE_DEVICES=7 python eval.py --model-folder /home/xiesicheng/chd/RVT/rvt/runs/rvt2/20250308_083942 --eval-datafolder ./data/test --tasks all --eval-episodes 25 --log-name log --device 0 --headless --model-name model_99.pth --loop 3
#
#
# # train
#
# CUDA_VISIBLE_DEVICES=1 python train.py --exp_cfg_path configs/rvt2.yaml --mvt_cfg_path mvt/configs/rvt2.yaml --device 0,1,2,3,4,5,6,7
#
# # log
#
# tensorboard --logdir=/home/xiesicheng/chd/RVT/rvt/runs/rvt2/20250228_114648_multi
#
# # TODO
# eval loss

# %%
import numpy as np

# 加载 .replay 文件（假设是 NumPy 格式）
replay_buffer = np.load('/home/xiesicheng/chd/RVT/rvt/replay/replay_train_down/close_jar/0.replay', allow_pickle=True)
for key in replay_buffer.keys():
    print(key)
# 打印文件内容
# print(replay_buffer)
# Out:
# demo
# keypoint_idx
# episode_idx
# keypoint_frame
# next_keypoint_frame
# sample_frame
# trans_action_indicies
# rot_grip_action_indicies
# gripper_pose
# lang_goal
# left_shoulder_rgb
# left_shoulder_depth
# left_shoulder_point_cloud
# right_shoulder_rgb
# right_shoulder_depth
# right_shoulder_point_cloud
# wrist_rgb
# wrist_depth
# wrist_point_cloud
# front_rgb
# front_depth
# front_point_cloud
# ignore_collisions
# low_dim_state
# front_camera_extrinsics
# front_camera_intrinsics
# left_shoulder_camera_extrinsics
# left_shoulder_camera_intrinsics
# right_shoulder_camera_extrinsics
# right_shoulder_camera_intrinsics
# wrist_camera_extrinsics
# wrist_camera_intrinsics
# lang_goal_embs
# action
# reward
# terminal
# timeout

# %%
import socket

def get_free_port():
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.bind(('127.0.0.1', 0))
    _, port = s.getsockname()
    s.close()
    return port

free_port = get_free_port()
print(f"空闲端口：{free_port}")
# Out:
# 空闲端口：40279

# %%
import torch
